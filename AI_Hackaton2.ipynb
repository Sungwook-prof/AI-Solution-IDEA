# %% [markdown]
# OpenVINO 준비

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %pip install -q "openvino>=2023.1.0"
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.5/40.5 MB 15.1 MB/s eta 0:00:00

# %%
# !pip install openvino-dev
# Out:
# Collecting openvino-dev
#   Downloading openvino_dev-2024.3.0-16041-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: defusedxml>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from openvino-dev) (0.7.1)
# Collecting networkx<=3.1.0 (from openvino-dev)
#   Downloading networkx-3.1-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: numpy<2.0.0,>=1.16.6 in /usr/local/lib/python3.10/dist-packages (from openvino-dev) (1.26.4)
# Requirement already satisfied: openvino-telemetry>=2023.2.1 in /usr/local/lib/python3.10/dist-packages (from openvino-dev) (2024.1.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from openvino-dev) (24.1)
# Requirement already satisfied: pyyaml>=5.4.1 in /usr/local/lib/python3.10/dist-packages (from openvino-dev) (6.0.2)
# Requirement already satisfied: requests>=2.25.1 in /usr/local/lib/python3.10/dist-packages (from openvino-dev) (2.32.3)
# Requirement already satisfied: openvino==2024.3.0 in /usr/local/lib/python3.10/dist-packages (from openvino-dev) (2024.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.25.1->openvino-dev) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.25.1->openvino-dev) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.25.1->openvino-dev) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.25.1->openvino-dev) (2024.7.4)
# Downloading openvino_dev-2024.3.0-16041-py3-none-any.whl (4.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 42.0 MB/s eta 0:00:00
# Downloading networkx-3.1-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 67.7 MB/s eta 0:00:00
# Installing collected packages: networkx, openvino-dev
#   Attempting uninstall: networkx
#     Found existing installation: networkx 3.3
#     Uninstalling networkx-3.3:
#       Successfully uninstalled networkx-3.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torch 2.3.1+cu121 requires nvidia-cublas-cu12==12.1.3.1; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.3.1+cu121 requires nvidia-cuda-cupti-cu12==12.1.105; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.3.1+cu121 requires nvidia-cuda-nvrtc-cu12==12.1.105; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.3.1+cu121 requires nvidia-cuda-runtime-cu12==12.1.105; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.3.1+cu121 requires nvidia-cudnn-cu12==8.9.2.26; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.3.1+cu121 requires nvidia-cufft-cu12==11.0.2.54; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.3.1+cu121 requires nvidia-curand-cu12==10.3.2.106; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.3.1+cu121 requires nvidia-cusolver-cu12==11.4.5.107; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.3.1+cu121 requires nvidia-cusparse-cu12==12.1.0.106; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.3.1+cu121 requires nvidia-nccl-cu12==2.20.5; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.3.1+cu121 requires nvidia-nvtx-cu12==12.1.105; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# Successfully installed networkx-3.1 openvino-dev-2024.3.0

# %% [markdown]
# keras 모델을 Intel OpenVINO IR 파일(xml, bin)로 한다.

# %%
import openvino
import openvino as ov
from openvino.tools.mo import convert_model

BASE_PATH = './drive/MyDrive/data/'
ov_model = convert_model(BASE_PATH+'bin/mobilenetv2_class')
ov.save_model(ov_model, BASE_PATH+'bin/mobilenetv2_class8.xml')
# Out:
# [ INFO ] MO command line tool is considered as the legacy conversion API as of OpenVINO 2023.2 release.
# In 2025.0 MO command line tool and openvino.tools.mo.convert_model() will be removed. Please use OpenVINO Model Converter (OVC) or openvino.convert_model(). OVC represents a lightweight alternative of MO and provides simplified model conversion API.
# Find more information about transition from MO to OVC at https://docs.openvino.ai/2023.2/openvino_docs_OV_Converter_UG_prepare_model_convert_model_MO_OVC_transition.html

# %% [markdown]
# ### 테스트 파일 목록으로 읽어와서 답안 출력하기.

# %%
# --------------------------- Step 1. Initialize OpenVINO Runtime Core ------------------------------------------------
core = ov.Core()

# %%
# --------------------------- Step 2. Read a model --------------------------------------------------------------------
# (.xml and .bin files) or (.onnx file)
model = core.read_model(BASE_PATH+'bin/mobilenetv2_class8.xml')

if len(model.inputs) != 1: print('Sample supports only single input topologies')
if len(model.outputs) != 1: print('Sample supports only single output topologies')

# %%
import os

directory_path = "./drive/MyDrive/data/val"

# Get a list of all files in the directory
folder_list = [f for f in os.listdir(directory_path) if os.path.isdir(os.path.join(directory_path, f))]

# Print the list of files
print("List of files in the directory:")
file_list = []
for folder in folder_list:
    flist = [f for f in os.listdir(directory_path+'/'+folder) if os.path.isfile(os.path.join(directory_path+'/'+folder, f))]
    for file in flist:
        file_list.append(directory_path+'/'+folder+"/"+file)
# 2008_004538.jpg
# 2008_005460.jpg
# 2008_003045.jpg
# 2008_003343.jpg
# 2008_004688.jpg
# 2008_004006.jpg
# 2008_000670.jpg
# 2008_004873.jpg
# 2008_004189.jpg
# 2008_000182.jpg
# 2008_002682.jpg
# 2008_005421.jpg
# 2008_005480.jpg
# 2008_003167.jpg
# 2008_000062.jpg
# 2008_004422.jpg
# 2008_000581.jpg
# 2008_003607.jpg
# 2008_003499.jpg
# 2008_003228.jpg
# 2008_001350.jpg
# 2008_003519.jpg
# 2008_005309.jpg
# 2008_000306.jpg
# 2008_004048.jpg
# 2008_001290.jpg
# 2008_001433.jpg
# 2008_002681.jpg
# 2008_001078.jpg
# 2008_004290.jpg
# 2008_005072.jpg
# 2008_005288.jpg
# 2008_000793.jpg
# 2008_000950.jpg
# 2008_004736.jpg
# 2008_003557.jpg
# 2008_004347.jpg
# 2008_003104.jpg
# 2008_004640.jpg
# 2008_002234.jpg
# 2008_000056.jpg
# 2008_004967.jpg
# 2008_003420.jpg
# 2008_004540.jpg
# 2008_000853.jpg
# 2008_004933.jpg
# 2008_001374.jpg
# 2008_005270.jpg
# 2008_005550.jpg

# %%
import pickle

with open(BASE_PATH+'bin/class8.pickle', 'rb') as f:
    labels = pickle.load(f)

# %% [markdown]
# 파일 추론하기

# %%
import pandas as pd
import cv2
import numpy as np

# --------------------------- Step 4. Loading model to the device -----------------------------------------------------
print('Loading the model to the plugin')
compiled_model = core.compile_model(model, 'CPU')
img_height = 224

result = []

res = open(BASE_PATH+"result.txt", "w")

print('Starting inference in synchronous mode')
cnt = 0;

for file in file_list:
    # --------------------------- Step 5. Set up input --------------------------------------------------------------------
    # Read input image
    image_path = file
    org_image = cv2.imread(image_path)
    image = cv2.resize(org_image, (img_height,img_height), fx=0.5, fy=0.5, interpolation=cv2.INTER_LINEAR)
    #img = cv2.resize(img, (224,224), fx=0.5, fy=0.5, interpolation=cv2.INTER_AREA)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image = image / 255.

    # Add N dimension
    nchw_tensor = np.expand_dims(image, 0)

    # NHWC -> NCHW
    input_tensor = np.transpose(nchw_tensor, (0,1,2,3))#(0,3,1,2))

    # --------------------------- Step 6. Create infer request and do inference synchronously -----------------------------
    results = compiled_model.infer_new_request({0:input_tensor})

    # --------------------------- Step 7. Process output ------------------------------------------------------------------
    predictions = next(iter(results.values()))
    output_node_name = next(iter(results.keys())) #

    # Change a shape of a numpy.ndarray with results to get another one with one dimension
    probs = predictions.reshape(-1)

    # Get an array of 8 class IDs in descending order of probability
    top_8 = np.argsort(probs)[-8:][::-1]
    print(top_8)

    header = 'class_id            probability'
    print(f'Image path: {image_path}')
    print('Top 8 results: ')
    print(header)
    print('-' * len(header))

    for class_id in top_8:
        probability_indent = ' ' * (len('class_id           ') - len(labels[class_id]) + 1)
        print(f'{labels[class_id]}{probability_indent}{probs[class_id]*100:.7f}')

    res.write(file+':top1 = ('+labels[top_8[0]]+')'+str(probs[top_8[0]]*100)+', top2 = ('+labels[top_8[1]]+')'+str(probs[top_8[1]]*100)+'\n')

res.close()
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# bottle              99.9984145
# cat                 0.0013422
# car                 0.0001848
# bird                0.0000285
# bicycle             0.0000131
# boat                0.0000129
# aeroplane           0.0000017
# bus                 0.0000003
# [4 6 0 1 2 5 3 7]
# Image path: ./drive/MyDrive/data/val/bottle/2008_001060.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# bottle              99.4892359
# car                 0.3471196
# aeroplane           0.1094101
# bicycle             0.0330869
# bird                0.0156081
# bus                 0.0050358
# boat                0.0002676
# cat                 0.0002352
# [4 7 6 1 2 0 3 5]
# Image path: ./drive/MyDrive/data/val/bottle/2008_002775.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# bottle              99.9999762
# cat                 0.0000122
# car                 0.0000061
# bicycle             0.0000005
# bird                0.0000003
# aeroplane           0.0000001
# boat                0.0000000
# bus                 0.0000000
# [4 6 2 1 7 5 3 0]
# Image path: ./drive/MyDrive/data/val/bottle/2008_004417.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# bottle              99.5943010
# car                 0.2390520
# bird                0.1570798
# bicycle             0.0046420
# cat                 0.0040496
# bus                 0.0006477
# boat                0.0001824
# aeroplane           0.0000525
# [4 3 7 6 1 2 0 5]
# Image path: ./drive/MyDrive/data/val/bottle/2008_004487.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# bottle              96.1119950
# boat                1.4171552
# cat                 1.2873691
# car                 0.9730259
# bicycle             0.1283423
# bird                0.0409443
# aeroplane           0.0389716
# bus                 0.0021961
# [4 6 7 3 5 1 0 2]
# Image path: ./drive/MyDrive/data/val/bottle/2008_003722.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# bottle              98.7064004
# car                 1.2611881
# cat                 0.0277597
# boat                0.0036889
# bus                 0.0003958
# bicycle             0.0003120
# aeroplane           0.0001463
# bird                0.0001138
# [4 7 6 1 2 0 3 5]
# Image path: ./drive/MyDrive/data/val/bottle/2008_000034.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# bottle              99.9996901
# cat                 0.0001887
# car                 0.0001188
# bicycle             0.0000060
# bird                0.0000028
# aeroplane           0.0000022
# boat                0.0000013
# bus                 0.0000000
# [4 6 7 0 1 3 2 5]
# Image path: ./drive/MyDrive/data/val/bottle/2008_006027.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# bottle              99.9943137
# car                 0.0055878
# cat                 0.0000370
# aeroplane           0.0000301
# bicycle             0.0000133
# boat                0.0000061
# bird                0.0000047
# bus                 0.0000045
# [4 7 6 0 2 5 1 3]
# Image path: ./drive/MyDrive/data/val/bottle/2008_005023.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# bottle              96.4171469
# cat                 3.4980137
# car                 0.0730023
# aeroplane           0.0090202
# bird                0.0011263
# bus                 0.0009531
# bicycle             0.0005188
# boat                0.0002157
# [4 7 3 6 2 1 0 5]
# Image path: ./drive/MyDrive/data/val/bottle/2008_003621.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# bottle              99.5662391
# cat                 0.2130948
# boat                0.1992058
# car                 0.0076862
# bird                0.0071431
# bicycle             0.0054083
# aeroplane           0.0011324
# bus                 0.0001027
# [4 7 6 2 3 1 5 0]
# Image path: ./drive/MyDrive/data/val/bottle/2008_006104.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# bottle              99.9975562
# cat                 0.0018254
# car                 0.0006003
# bird                0.0000095
# boat                0.0000055
# bicycle             0.0000026
# bus                 0.0000018
# aeroplane           0.0000007
# [7 4 6 5 2 3 0 1]
# Image path: ./drive/MyDrive/data/val/bottle/2008_004126.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# cat                 80.9975445
# bottle              13.8690874
# car                 2.7357990
# bus                 1.0488775
# bird                0.9740426
# boat                0.2622770
# aeroplane           0.0848139
# bicycle             0.0275532
# [4 2 7 6 3 1 0 5]
# Image path: ./drive/MyDrive/data/val/bottle/2008_005939.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# bottle              99.4944274
# bird                0.2362132
# cat                 0.1642550
# car                 0.0991876
# boat                0.0021708
# bicycle             0.0016095
# aeroplane           0.0015339
# bus                 0.0006101
# [4 6 0 2 5 7 3 1]
# Image path: ./drive/MyDrive/data/val/bottle/2008_004090.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# bottle              99.7846007
# car                 0.1909764
# aeroplane           0.0141869
# bird                0.0045925
# bus                 0.0034326
# cat                 0.0012700
# boat                0.0005402
# bicycle             0.0004013
# [4 6 5 7 0 2 1 3]
# Image path: ./drive/MyDrive/data/val/bottle/2008_004431.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# bottle              99.9900103
# car                 0.0099819
# bus                 0.0000094
# cat                 0.0000035
# aeroplane           0.0000011
# bird                0.0000006
# bicycle             0.0000003
# boat                0.0000001
# [6 5 4 3 1 7 0 2]
# Image path: ./drive/MyDrive/data/val/bottle/2008_004501.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# car                 45.9193170
# bus                 27.5117695
# bottle              24.8763338
# boat                0.8874048
# bicycle             0.4504106
# cat                 0.1716774
# aeroplane           0.1235206
# bird                0.0595614
# [4 0 1 6 7 2 3 5]
# Image path: ./drive/MyDrive/data/val/bottle/2008_001304.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# bottle              98.2725978
# aeroplane           0.8772817
# bicycle             0.6979587
# car                 0.0877323
# cat                 0.0390363
# bird                0.0103519
# boat                0.0099307
# bus                 0.0051078
# [4 6 7 0 2 1 3 5]
# Image path: ./drive/MyDrive/data/val/bottle/2008_001593.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# bottle              99.6950626
# car                 0.2495397
# cat                 0.0233576
# aeroplane           0.0195924
# bird                0.0078105
# bicycle             0.0041037
# boat                0.0003942
# bus                 0.0001284
# [4 7 2 1 0 3 6 5]
# Image path: ./drive/MyDrive/data/val/bottle/2008_004795.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# bottle              97.0041096
# cat                 2.9557806
# bird                0.0238408
# bicycle             0.0100049
# aeroplane           0.0020481
# boat                0.0017928
# car                 0.0012919
# bus                 0.0011414
# [4 6 0 7 1 3 2 5]
# Image path: ./drive/MyDrive/data/val/bottle/2008_001333.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# bottle              98.3997583
# car                 0.9854470
# aeroplane           0.5845158
# cat                 0.0259252
# bicycle             0.0026159
# boat                0.0008243
# bird                0.0006961
# bus                 0.0002216
# [4 7 6 1 3 2 0 5]
# Image path: ./drive/MyDrive/data/val/bottle/2008_003280.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# bottle              99.2257714
# cat                 0.7010430
# car                 0.0413099
# bicycle             0.0144287
# boat                0.0076029
# bird                0.0050164
# aeroplane           0.0045655
# bus                 0.0002661
# [4 7 1 6 2 3 5 0]
# Image path: ./drive/MyDrive/data/val/bottle/2008_004460.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# bottle              99.8652041
# cat                 0.1277735
# bicycle             0.0022234
# car                 0.0017608
# bird                0.0017260
# boat                0.0012322
# bus                 0.0000562
# aeroplane           0.0000190
# [4 7 6 2 3 1 0 5]
# Image path: ./drive/MyDrive/data/val/bottle/2008_004389.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# bottle              99.9283850
# cat                 0.0683793
# car                 0.0016868
# bird                0.0010726
# boat                0.0002124
# bicycle             0.0001968
# aeroplane           0.0000591
# bus                 0.0000103
# [4 7 6 3 1 0 2 5]
# Image path: ./drive/MyDrive/data/val/bottle/2008_002124.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# bottle              60.5584562
# cat                 36.9789451
# car                 2.2652349
# boat                0.1286745
# bicycle             0.0375899
# aeroplane           0.0253038
# bird                0.0045864
# bus                 0.0012088
# [4 7 6 2 1 3 5 0]
# Image path: ./drive/MyDrive/data/val/bottle/2008_003467.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# bottle              99.9998689
# cat                 0.0001356
# car                 0.0000016
# bird                0.0000003
# bicycle             0.0000001
# boat                0.0000000
# bus                 0.0000000
# aeroplane           0.0000000
# [4 1 7 6 3 2 0 5]
# Image path: ./drive/MyDrive/data/val/bottle/2008_005347.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# bottle              95.0210035
# bicycle             4.4118334
# cat                 0.2612869
# car                 0.2512485
# boat                0.0368255
# bird                0.0104849
# aeroplane           0.0040018
# bus                 0.0033254
# [4 6 1 5 2 0 7 3]
# Image path: ./drive/MyDrive/data/val/bottle/2008_004016.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# bottle              97.9206800
# car                 2.0254876
# bicycle             0.0215511
# bus                 0.0139188
# bird                0.0085998
# aeroplane           0.0052243
# cat                 0.0032813
# boat                0.0012493
# [4 7 1 6 5 2 3 0]
# Image path: ./drive/MyDrive/data/val/bottle/2008_004898.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# bottle              93.8197434
# cat                 4.0513407
# bicycle             1.5809728
# car                 0.2065718
# bus                 0.1832302
# bird                0.1354541
# boat                0.0212312
# aeroplane           0.0014514
# [4 7 6 1 2 5 3 0]
# Image path: ./drive/MyDrive/data/val/bottle/2008_002789.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# bottle              95.9046066
# cat                 3.5164189
# car                 0.2508957
# bicycle             0.2023196
# bird                0.0935811
# bus                 0.0177620
# boat                0.0097723
# aeroplane           0.0046448
# [4 7 6 0 2 1 5 3]
# Image path: ./drive/MyDrive/data/val/bottle/2008_000522.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# bottle              99.9977589
# cat                 0.0017960
# car                 0.0003405
# aeroplane           0.0000633
# bird                0.0000199
# bicycle             0.0000195
# bus                 0.0000089
# boat                0.0000022
# [4 6 0 7 3 2 1 5]
# Image path: ./drive/MyDrive/data/val/bottle/2008_002909.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# bottle              99.9443591
# car                 0.0517241
# aeroplane           0.0019015
# cat                 0.0015635
# boat                0.0003465
# bird                0.0000557
# bicycle             0.0000346
# bus                 0.0000133
# [4 5 6 7 1 2 3 0]
# Image path: ./drive/MyDrive/data/val/bottle/2008_002086.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# bottle              98.7573028
# bus                 0.9471563
# car                 0.1872108
# cat                 0.0605537
# bicycle             0.0286689
# bird                0.0170551
# boat                0.0014517
# aeroplane           0.0006039
# [4 7 6 2 0 1 3 5]
# Image path: ./drive/MyDrive/data/val/bottle/2008_002153.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# bottle              99.9720275
# cat                 0.0142453
# car                 0.0067753
# bird                0.0037342
# aeroplane           0.0022096
# bicycle             0.0006611
# boat                0.0003356
# bus                 0.0000157
# [5 6 4 0 1 2 7 3]
# Image path: ./drive/MyDrive/data/val/bottle/2008_001636.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# bus                 41.8509811
# car                 30.6362659
# bottle              23.2365564
# aeroplane           1.6369078
# bicycle             1.2315928
# bird                0.9450674
# cat                 0.2750185
# boat                0.1876129
# [4 2 7 0 5 6 3 1]
# Image path: ./drive/MyDrive/data/val/bottle/2008_005182.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# bottle              99.8943508
# bird                0.0677731
# cat                 0.0312680
# aeroplane           0.0025109
# bus                 0.0016381
# car                 0.0014683
# boat                0.0006065
# bicycle             0.0003827
# [4 7 6 3 1 2 5 0]
# Image path: ./drive/MyDrive/data/val/bottle/2008_005204.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# bottle              100.0000000
# cat                 0.0000023
# car                 0.0000013
# boat                0.0000002
# bicycle             0.0000000
# bird                0.0000000
# bus                 0.0000000
# aeroplane           0.0000000
# [4 6 5 3 2 7 0 1]
# Image path: ./drive/MyDrive/data/val/bottle/2008_001638.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# bottle              98.4590888
# car                 0.9789806
# bus                 0.4369914
# boat                0.1045051
# bird                0.0105206
# cat                 0.0033517
# aeroplane           0.0033294
# bicycle             0.0032298
# [4 7 6 1 2 0 5 3]
# Image path: ./drive/MyDrive/data/val/bottle/2008_004778.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# bottle              99.9985576
# cat                 0.0011447
# car                 0.0002449
# bicycle             0.0000215
# bird                0.0000183
# aeroplane           0.0000117
# bus                 0.0000026
# boat                0.0000024
# [4 7 6 1 2 3 0 5]
# Image path: ./drive/MyDrive/data/val/bottle/2008_000885.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# bottle              99.9976873
# cat                 0.0011450
# car                 0.0005103
# bicycle             0.0002876
# bird                0.0001993
# boat                0.0001472
# aeroplane           0.0000087
# bus                 0.0000005
# [4 3 7 6 1 2 5 0]
# Image path: ./drive/MyDrive/data/val/bottle/2008_002082.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# bottle              99.5942771
# boat                0.1610513
# cat                 0.1506106
# car                 0.0453739
# bicycle             0.0424128
# bird                0.0040459
# bus                 0.0018595
# aeroplane           0.0003578
# [4 1 6 2 5 7 3 0]
# Image path: ./drive/MyDrive/data/val/bottle/2008_004384.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# bottle              66.7059124
# bicycle             16.9006258
# car                 16.1414996
# bird                0.1185233
# bus                 0.0898535
# cat                 0.0299137
# boat                0.0092175
# aeroplane           0.0044494
# [4 7 2 6 0 5 1 3]
# Image path: ./drive/MyDrive/data/val/bottle/2008_005904.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# bottle              99.9885798
# cat                 0.0110106
# bird                0.0003463
# car                 0.0000424
# aeroplane           0.0000065
# bus                 0.0000040
# bicycle             0.0000020
# boat                0.0000017
# [6 4 5 0 3 1 7 2]
# Image path: ./drive/MyDrive/data/val/bottle/2008_002199.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# car                 83.3099306
# bottle              15.8466369
# bus                 0.4124148
# aeroplane           0.2813174
# boat                0.0768682
# bicycle             0.0418073
# cat                 0.0285791
# bird                0.0024433
# [4 7 3 6 1 2 0 5]
# Image path: ./drive/MyDrive/data/val/bottle/2008_001077.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# bottle              99.9863625
# cat                 0.0105608
# boat                0.0021413
# car                 0.0006114
# bicycle             0.0001655
# bird                0.0001198
# aeroplane           0.0000325
# bus                 0.0000004
# [4 6 0 2 1 7 3 5]
# Image path: ./drive/MyDrive/data/val/bottle/2008_004056.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# bottle              70.8041012
# car                 27.4183422
# aeroplane           0.9705556
# bird                0.7190340
# bicycle             0.0727527
# cat                 0.0129708
# boat                0.0014412
# bus                 0.0007999
# [4 6 5 7 0 3 2 1]
# Image path: ./drive/MyDrive/data/val/bottle/2008_000795.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# bottle              99.9439061
# car                 0.0495831
# bus                 0.0020817
# cat                 0.0016025
# aeroplane           0.0012310
# boat                0.0009364
# bird                0.0006463
# bicycle             0.0000169
# [4 7 1 6 2 5 3 0]
# Image path: ./drive/MyDrive/data/val/bottle/2008_002378.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# bottle              99.9920607
# cat                 0.0057177
# bicycle             0.0015853
# car                 0.0003114
# bird                0.0001915
# bus                 0.0001121
# boat                0.0000191
# aeroplane           0.0000017
# [3 4 6 7 5 0 2 1]
# Image path: ./drive/MyDrive/data/val/bottle/2008_001594.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# boat                37.6906514
# bottle              29.5747191
# car                 26.3142049
# cat                 4.8684705
# bus                 1.0561673
# aeroplane           0.3945137
# bird                0.0982541
# bicycle             0.0030174
# [4 6 7 2 0 5 3 1]
# Image path: ./drive/MyDrive/data/val/bottle/2008_005140.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# bottle              99.9998569
# car                 0.0001119
# cat                 0.0000223
# bird                0.0000037
# aeroplane           0.0000006
# bus                 0.0000003
# boat                0.0000002
# bicycle             0.0000002
# [4 7 6 2 5 1 3 0]
# Image path: ./drive/MyDrive/data/val/bottle/2008_005677.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# bottle              99.9980807
# cat                 0.0016714
# car                 0.0002279
# bird                0.0000150
# bus                 0.0000133
# bicycle             0.0000003
# boat                0.0000003
# aeroplane           0.0000001
# [4 7 2 6 0 3 1 5]
# Image path: ./drive/MyDrive/data/val/bottle/2008_004308.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# bottle              99.9916077
# cat                 0.0037128
# bird                0.0017125
# car                 0.0014932
# aeroplane           0.0013019
# boat                0.0001485
# bicycle             0.0000222
# bus                 0.0000019
# [6 0 3 4 5 1 7 2]
# Image path: ./drive/MyDrive/data/val/bottle/2008_000261.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# car                 99.5755196
# aeroplane           0.2348064
# boat                0.0933235
# bottle              0.0493238
# bus                 0.0448400
# bicycle             0.0014778
# cat                 0.0005457
# bird                0.0001715
# [4 7 1 6 2 3 5 0]
# Image path: ./drive/MyDrive/data/val/bottle/2008_002864.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# bottle              99.9995828
# cat                 0.0002997
# bicycle             0.0000644
# car                 0.0000415
# bird                0.0000016
# boat                0.0000013
# bus                 0.0000001
# aeroplane           0.0000001
# [6 0 3 5 4 1 2 7]
# Image path: ./drive/MyDrive/data/val/bottle/2008_002250.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# car                 75.2259195
# aeroplane           15.9628525
# boat                8.7061368
# bus                 0.0547458
# bottle              0.0411737
# bicycle             0.0067794
# bird                0.0012493
# cat                 0.0011464
# [4 6 7 1 2 5 0 3]
# Image path: ./drive/MyDrive/data/val/bottle/2008_005881.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# bottle              99.9005258
# car                 0.0857786
# cat                 0.0122156
# bicycle             0.0010426
# bird                0.0002163
# bus                 0.0001035
# aeroplane           0.0001031
# boat                0.0000121
# [4 7 6 1 2 0 3 5]
# Image path: ./drive/MyDrive/data/val/bottle/2008_005812.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# bottle              99.9927521
# cat                 0.0069519
# car                 0.0002604
# bicycle             0.0000156
# bird                0.0000110
# aeroplane           0.0000018
# boat                0.0000006
# bus                 0.0000001
# [4 0 6 3 7 2 5 1]
# Image path: ./drive/MyDrive/data/val/bottle/2008_002372.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# bottle              83.2949758
# aeroplane           8.5880205
# car                 6.2995173
# boat                1.6371135
# cat                 0.1310582
# bird                0.0315366
# bus                 0.0149051
# bicycle             0.0028654
# [4 7 2 6 1 3 0 5]
# Image path: ./drive/MyDrive/data/val/bottle/2008_000398.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# bottle              99.9979496
# cat                 0.0014663
# bird                0.0004436
# car                 0.0001170
# bicycle             0.0000189
# boat                0.0000040
# aeroplane           0.0000010
# bus                 0.0000004
# [4 7 6 2 0 1 3 5]
# Image path: ./drive/MyDrive/data/val/bottle/2008_004659.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# bottle              99.9998212
# cat                 0.0001242
# car                 0.0000263
# bird                0.0000206
# aeroplane           0.0000013
# bicycle             0.0000010
# boat                0.0000004
# bus                 0.0000002
# [4 6 1 0 3 7 5 2]
# Image path: ./drive/MyDrive/data/val/bottle/2008_001928.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# bottle              99.9117792
# car                 0.0849553
# bicycle             0.0019334
# aeroplane           0.0008752
# boat                0.0001664
# cat                 0.0001586
# bus                 0.0000986
# bird                0.0000410
# [4 3 2 6 7 0 1 5]
# Image path: ./drive/MyDrive/data/val/bottle/2008_006052.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# bottle              99.9951601
# boat                0.0014349
# bird                0.0011033
# car                 0.0009932
# cat                 0.0009449
# aeroplane           0.0002524
# bicycle             0.0000699
# bus                 0.0000359
# [4 6 1 7 2 5 3 0]
# Image path: ./drive/MyDrive/data/val/bottle/2008_000145.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# bottle              89.8028314
# car                 6.1094284
# bicycle             1.8294487
# cat                 1.0906264
# bird                0.4879865
# bus                 0.3518400
# boat                0.2506903
# aeroplane           0.0771485
# [4 6 7 3 2 0 5 1]
# Image path: ./drive/MyDrive/data/val/bottle/2008_005869.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# bottle              99.9967694
# car                 0.0028397
# cat                 0.0003578
# boat                0.0000177
# bird                0.0000095
# aeroplane           0.0000030
# bus                 0.0000011
# bicycle             0.0000004
# [4 6 1 0 5 2 3 7]
# Image path: ./drive/MyDrive/data/val/bottle/2008_000677.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# bottle              99.8445094
# car                 0.1310330
# bicycle             0.0192885
# aeroplane           0.0016421
# bus                 0.0014525
# bird                0.0011005
# boat                0.0007362
# cat                 0.0002468
# [4 6 7 0 2 1 5 3]
# Image path: ./drive/MyDrive/data/val/bottle/2008_003969.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# bottle              99.7819901
# car                 0.1263441
# cat                 0.0862681
# aeroplane           0.0022876
# bird                0.0014411
# bicycle             0.0008847
# bus                 0.0006013
# boat                0.0001809
# [4 7 6 3 5 2 1 0]
# Image path: ./drive/MyDrive/data/val/bottle/2008_004178.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# bottle              99.9366224
# cat                 0.0350145
# car                 0.0203481
# boat                0.0037498
# bus                 0.0016875
# bird                0.0013911
# bicycle             0.0009690
# aeroplane           0.0002146
# [4 6 7 1 5 0 2 3]
# Image path: ./drive/MyDrive/data/val/bottle/2008_003186.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# bottle              98.1256545
# car                 1.8187396
# cat                 0.0283658
# bicycle             0.0095207
# bus                 0.0075543
# aeroplane           0.0043557
# bird                0.0042779
# boat                0.0015337
# [4 6 7 0 2 5 1 3]
# Image path: ./drive/MyDrive/data/val/bottle/2008_006072.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# bottle              99.9990225
# car                 0.0009027
# cat                 0.0000665
# aeroplane           0.0000046
# bird                0.0000013
# bus                 0.0000005
# bicycle             0.0000003
# boat                0.0000001
# [4 6 0 7 1 2 5 3]
# Image path: ./drive/MyDrive/data/val/bottle/2008_002292.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# bottle              99.9886274
# car                 0.0072890
# aeroplane           0.0034473
# cat                 0.0002711
# bicycle             0.0002504
# bird                0.0001164
# bus                 0.0000039
# boat                0.0000027
# [4 7 6 2 3 1 0 5]
# Image path: ./drive/MyDrive/data/val/bottle/2008_001862.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# bottle              93.9137399
# cat                 5.0766282
# car                 0.7231391
# bird                0.1517118
# boat                0.1312026
# bicycle             0.0021357
# aeroplane           0.0010106
# bus                 0.0004348
# [4 6 1 7 2 5 3 0]
# Image path: ./drive/MyDrive/data/val/bottle/2008_005089.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# bottle              99.4048238
# car                 0.3041158
# bicycle             0.1212159
# cat                 0.0681413
# bird                0.0474399
# bus                 0.0302833
# boat                0.0190203
# aeroplane           0.0049650
# [4 7 6 1 2 3 0 5]
# Image path: ./drive/MyDrive/data/val/bottle/2008_001486.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# bottle              99.9892235
# cat                 0.0072741
# car                 0.0017295
# bicycle             0.0014262
# bird                0.0002602
# boat                0.0000349
# aeroplane           0.0000316
# bus                 0.0000101
# [4 7 2 6 1 5 0 3]
# Image path: ./drive/MyDrive/data/val/bottle/2008_001629.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# bottle              96.5477049
# cat                 2.9041681
# bird                0.2677350
# car                 0.2561393
# bicycle             0.0127636
# bus                 0.0099869
# aeroplane           0.0008142
# boat                0.0006878
# [4 6 7 0 1 5 3 2]
# Image path: ./drive/MyDrive/data/val/bottle/2008_002606.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# bottle              99.9442041
# car                 0.0383792
# cat                 0.0113230
# aeroplane           0.0032423
# bicycle             0.0015850
# bus                 0.0006821
# boat                0.0004185
# bird                0.0001624
# [4 6 7 0 1 3 2 5]
# Image path: ./drive/MyDrive/data/val/bottle/2008_005646.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# bottle              99.9150753
# car                 0.0628723
# cat                 0.0119771
# aeroplane           0.0062424
# bicycle             0.0017084
# boat                0.0013893
# bird                0.0006253
# bus                 0.0001132
# [4 7 2 3 6 0 1 5]
# Image path: ./drive/MyDrive/data/val/bottle/2008_002330.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# bottle              99.9208868
# cat                 0.0479068
# bird                0.0204350
# boat                0.0059143
# car                 0.0024830
# aeroplane           0.0017984
# bicycle             0.0005031
# bus                 0.0000804
# [4 7 2 0 3 6 1 5]
# Image path: ./drive/MyDrive/data/val/bottle/2008_004982.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# bottle              99.9680161
# cat                 0.0300459
# bird                0.0017733
# aeroplane           0.0000654
# boat                0.0000582
# car                 0.0000469
# bicycle             0.0000035
# bus                 0.0000002
# [4 7 6 2 1 0 5 3]
# Image path: ./drive/MyDrive/data/val/bottle/2008_001199.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# bottle              100.0000000
# cat                 0.0000025
# car                 0.0000007
# bird                0.0000001
# bicycle             0.0000001
# aeroplane           0.0000000
# bus                 0.0000000
# boat                0.0000000
# [4 6 0 7 2 3 5 1]
# Image path: ./drive/MyDrive/data/val/bottle/2008_001910.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# bottle              98.2274115
# car                 0.9446834
# aeroplane           0.3496602
# cat                 0.1944146
# bird                0.1701440
# boat                0.0664018
# bus                 0.0295477
# bicycle             0.0177387
# [4 7 6 2 1 3 5 0]
# Image path: ./drive/MyDrive/data/val/bottle/2008_004926.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# bottle              99.9999642
# cat                 0.0000194
# car                 0.0000152
# bird                0.0000015
# bicycle             0.0000002
# boat                0.0000000
# bus                 0.0000000
# aeroplane           0.0000000
# [4 6 7 1 5 2 3 0]
# Image path: ./drive/MyDrive/data/val/bottle/2008_004814.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# bottle              99.7816443
# car                 0.1223332
# cat                 0.0913248
# bicycle             0.0024827
# bus                 0.0009775
# bird                0.0007151
# boat                0.0004826
# aeroplane           0.0000321
# [4 6 3 5 0 1 2 7]
# Image path: ./drive/MyDrive/data/val/bottle/2008_000705.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# bottle              45.5329180
# car                 40.9756273
# boat                5.8385357
# bus                 3.8238354
# aeroplane           3.2968465
# bicycle             0.3781971
# bird                0.1097691
# cat                 0.0442685
# [4 6 7 0 1 3 2 5]
# Image path: ./drive/MyDrive/data/val/bottle/2008_005399.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# bottle              99.9970436
# car                 0.0019691
# cat                 0.0008878
# aeroplane           0.0000393
# bicycle             0.0000362
# boat                0.0000134
# bird                0.0000061
# bus                 0.0000011
# [4 6 7 0 2 5 3 1]
# Image path: ./drive/MyDrive/data/val/bottle/2008_002870.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# bottle              99.9336898
# car                 0.0430788
# cat                 0.0230928
# aeroplane           0.0000739
# bird                0.0000352
# bus                 0.0000146
# boat                0.0000138
# bicycle             0.0000045
# [4 7 6 1 3 2 0 5]
# Image path: ./drive/MyDrive/data/val/bottle/2008_000691.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# bottle              99.9182403
# cat                 0.0814646
# car                 0.0002561
# bicycle             0.0000148
# boat                0.0000135
# bird                0.0000043
# aeroplane           0.0000013
# bus                 0.0000006
# [4 6 5 1 0 3 2 7]
# Image path: ./drive/MyDrive/data/val/car/2008_003132.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# bottle              68.8973606
# car                 21.7965841
# bus                 9.1386765
# bicycle             0.0911422
# aeroplane           0.0361784
# boat                0.0202757
# bird                0.0162114
# cat                 0.0035670
# [6 7 4 1 2 5 3 0]
# Image path: ./drive/MyDrive/data/val/car/2008_003829.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# car                 75.5512178
# cat                 8.9576147
# bottle              7.8529850
# bicycle             4.2779271
# bird                2.1611840
# bus                 1.1225655
# boat                0.0522352
# aeroplane           0.0242693
# [6 3 0 5 7 4 1 2]
# Image path: ./drive/MyDrive/data/val/car/2008_001961.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# car                 94.7975874
# boat                2.5709089
# aeroplane           1.3414654
# bus                 1.1453805
# cat                 0.1017944
# bottle              0.0245438
# bicycle             0.0147269
# bird                0.0035966
# [6 5 0 3 1 2 7 4]
# Image path: ./drive/MyDrive/data/val/car/2008_003794.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# car                 98.8617480
# bus                 0.5444320
# aeroplane           0.4933642
# boat                0.0442551
# bicycle             0.0425741
# bird                0.0055927
# cat                 0.0053092
# bottle              0.0027271
# [6 5 1 0 3 4 7 2]
# Image path: ./drive/MyDrive/data/val/car/2008_000457.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# car                 87.9619539
# bus                 11.1247122
# bicycle             0.5453005
# aeroplane           0.2413567
# boat                0.0607192
# bottle              0.0520523
# cat                 0.0077745
# bird                0.0061386
# [4 6 1 0 5 3 2 7]
# Image path: ./drive/MyDrive/data/val/car/2008_003202.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# bottle              58.3984673
# car                 31.8851352
# bicycle             3.1019654
# aeroplane           2.6931593
# bus                 1.9244688
# boat                1.6245287
# bird                0.2824322
# cat                 0.0898403
# [6 5 1 0 4 3 2 7]
# Image path: ./drive/MyDrive/data/val/car/2008_001586.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# car                 85.8582675
# bus                 10.2140769
# bicycle             3.8941357
# aeroplane           0.0215546
# bottle              0.0061423
# boat                0.0047747
# bird                0.0007164
# cat                 0.0003288
# [6 0 4 3 7 5 2 1]
# Image path: ./drive/MyDrive/data/val/car/2008_000939.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# car                 98.9417970
# aeroplane           0.9263757
# bottle              0.0987505
# boat                0.0118770
# cat                 0.0093714
# bus                 0.0085432
# bird                0.0017230
# bicycle             0.0015583
# [6 5 1 4 0 3 7 2]
# Image path: ./drive/MyDrive/data/val/car/2008_003680.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# car                 99.8658895
# bus                 0.1077229
# bicycle             0.0123665
# bottle              0.0113702
# aeroplane           0.0019589
# boat                0.0003687
# cat                 0.0002104
# bird                0.0001062
# [6 5 1 3 4 0 7 2]
# Image path: ./drive/MyDrive/data/val/car/2008_003255.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# car                 62.3056829
# bus                 37.4768972
# bicycle             0.1654636
# boat                0.0221949
# bottle              0.0163109
# aeroplane           0.0105097
# cat                 0.0015921
# bird                0.0013445
# [5 6 1 3 4 0 7 2]
# Image path: ./drive/MyDrive/data/val/car/2008_003030.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# bus                 83.3527207
# car                 16.6437447
# bicycle             0.0025632
# boat                0.0006678
# bottle              0.0001361
# aeroplane           0.0001192
# cat                 0.0000394
# bird                0.0000030
# [6 5 3 0 2 1 4 7]
# Image path: ./drive/MyDrive/data/val/car/2008_002705.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# car                 78.9367139
# bus                 20.7546324
# boat                0.2132672
# aeroplane           0.0558246
# bird                0.0124394
# bicycle             0.0123856
# bottle              0.0105691
# cat                 0.0041597
# [6 1 5 4 3 7 2 0]
# Image path: ./drive/MyDrive/data/val/car/2008_000868.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# car                 62.5785947
# bicycle             26.1882514
# bus                 10.9096780
# bottle              0.2212263
# boat                0.0408413
# cat                 0.0308590
# bird                0.0273724
# aeroplane           0.0031872
# [6 1 4 5 7 0 2 3]
# Image path: ./drive/MyDrive/data/val/car/2008_002322.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# car                 79.1899025
# bicycle             13.0190134
# bottle              6.5085120
# bus                 1.0490196
# cat                 0.0785946
# aeroplane           0.0702244
# bird                0.0464810
# boat                0.0382476
# [6 5 1 3 0 4 2 7]
# Image path: ./drive/MyDrive/data/val/car/2008_002401.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# car                 92.9657698
# bus                 5.6394171
# bicycle             0.8273711
# boat                0.5252196
# aeroplane           0.0167511
# bottle              0.0120870
# bird                0.0095234
# cat                 0.0038736
# [6 0 4 7 5 1 3 2]
# Image path: ./drive/MyDrive/data/val/car/2008_000163.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# car                 99.9761045
# aeroplane           0.0210614
# bottle              0.0015399
# cat                 0.0009503
# bus                 0.0001661
# bicycle             0.0001052
# boat                0.0000392
# bird                0.0000389
# [6 5 1 0 4 2 3 7]
# Image path: ./drive/MyDrive/data/val/car/2008_000880.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# car                 99.7767448
# bus                 0.0869706
# bicycle             0.0450776
# aeroplane           0.0302347
# bottle              0.0294083
# bird                0.0208928
# boat                0.0097664
# cat                 0.0009058
# [6 5 3 1 0 2 4 7]
# Image path: ./drive/MyDrive/data/val/car/2008_001830.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# car                 98.4643579
# bus                 1.3797053
# boat                0.0780692
# bicycle             0.0365137
# aeroplane           0.0210114
# bird                0.0094633
# bottle              0.0079194
# cat                 0.0029616
# [6 4 5 1 7 0 3 2]
# Image path: ./drive/MyDrive/data/val/car/2008_000952.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# car                 99.7362435
# bottle              0.2274118
# bus                 0.0121245
# bicycle             0.0110523
# cat                 0.0071641
# aeroplane           0.0056968
# boat                0.0002713
# bird                0.0000408
# [6 5 4 0 1 3 7 2]
# Image path: ./drive/MyDrive/data/val/car/2008_000599.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# car                 97.4548876
# bus                 1.4237176
# bottle              0.5512848
# aeroplane           0.4764756
# bicycle             0.0619670
# boat                0.0168921
# cat                 0.0115058
# bird                0.0032758
# [5 6 1 3 0 7 4 2]
# Image path: ./drive/MyDrive/data/val/car/2008_000982.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# bus                 62.4337018
# car                 36.9934410
# bicycle             0.3490882
# boat                0.1380979
# aeroplane           0.0405298
# cat                 0.0341026
# bottle              0.0068174
# bird                0.0042151
# [0 6 4 3 1 7 2 5]
# Image path: ./drive/MyDrive/data/val/car/2008_002138.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# aeroplane           99.7334123
# car                 0.2176919
# bottle              0.0288435
# boat                0.0105377
# bicycle             0.0061410
# cat                 0.0017990
# bird                0.0011187
# bus                 0.0004561
# [6 1 4 5 0 3 2 7]
# Image path: ./drive/MyDrive/data/val/car/2008_004142.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# car                 69.5323050
# bicycle             29.3711990
# bottle              0.8906349
# bus                 0.1795206
# aeroplane           0.0203766
# boat                0.0024575
# bird                0.0019864
# cat                 0.0015265
# [6 1 5 0 3 4 2 7]
# Image path: ./drive/MyDrive/data/val/car/2008_003082.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# car                 89.9831951
# bicycle             4.6739593
# bus                 3.8856875
# aeroplane           0.9839930
# boat                0.2463036
# bottle              0.1233431
# bird                0.0899041
# cat                 0.0136165
# [6 1 7 5 4 0 2 3]
# Image path: ./drive/MyDrive/data/val/car/2008_004046.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# car                 63.2673025
# bicycle             12.1413603
# cat                 10.9857090
# bus                 8.4775642
# bottle              3.2497548
# aeroplane           1.0174781
# bird                0.5459956
# boat                0.3148268
# [6 4 3 0 2 5 7 1]
# Image path: ./drive/MyDrive/data/val/car/2008_003943.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# car                 99.9985933
# bottle              0.0005947
# boat                0.0003778
# aeroplane           0.0001591
# bird                0.0001138
# bus                 0.0001091
# cat                 0.0000281
# bicycle             0.0000258
# [6 4 5 1 2 0 3 7]
# Image path: ./drive/MyDrive/data/val/car/2008_003350.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# car                 96.6380060
# bottle              1.4130702
# bus                 0.6921803
# bicycle             0.5313278
# bird                0.4616580
# aeroplane           0.2308500
# boat                0.0264149
# cat                 0.0064929
# [6 3 0 7 1 4 5 2]
# Image path: ./drive/MyDrive/data/val/car/2008_000501.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# car                 53.8382649
# boat                43.4544235
# aeroplane           2.3768950
# cat                 0.1614476
# bicycle             0.1107217
# bottle              0.0299754
# bus                 0.0204954
# bird                0.0077783
# [6 4 3 0 5 2 7 1]
# Image path: ./drive/MyDrive/data/val/car/2008_003022.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# car                 99.2880464
# bottle              0.3861945
# boat                0.2365614
# aeroplane           0.0744809
# bus                 0.0103664
# bird                0.0025090
# cat                 0.0015471
# bicycle             0.0002951
# [6 1 5 0 7 4 3 2]
# Image path: ./drive/MyDrive/data/val/car/2008_000659.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# car                 91.4106786
# bicycle             7.9986915
# bus                 0.2164127
# aeroplane           0.1741069
# cat                 0.0938594
# bottle              0.0852713
# boat                0.0167864
# bird                0.0041914
# [6 5 0 4 7 2 3 1]
# Image path: ./drive/MyDrive/data/val/car/2008_004069.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# car                 99.9994636
# bus                 0.0005049
# aeroplane           0.0000178
# bottle              0.0000028
# cat                 0.0000027
# bird                0.0000017
# boat                0.0000011
# bicycle             0.0000000
# [1 6 5 4 7 3 2 0]
# Image path: ./drive/MyDrive/data/val/car/2008_000562.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# bicycle             72.0667958
# car                 24.0767226
# bus                 2.3368135
# bottle              1.4322154
# cat                 0.0382978
# boat                0.0192579
# bird                0.0174069
# aeroplane           0.0124925
# [6 1 4 5 0 7 2 3]
# Image path: ./drive/MyDrive/data/val/car/2008_002643.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# car                 85.8039677
# bicycle             13.5956630
# bottle              0.4872106
# bus                 0.0540696
# aeroplane           0.0327510
# cat                 0.0253998
# bird                0.0007854
# boat                0.0001461
# [6 4 0 1 3 5 7 2]
# Image path: ./drive/MyDrive/data/val/car/2008_003577.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# car                 99.9933124
# bottle              0.0042353
# aeroplane           0.0022753
# bicycle             0.0001355
# boat                0.0000376
# bus                 0.0000077
# cat                 0.0000017
# bird                0.0000010
# [6 7 4 1 2 5 0 3]
# Image path: ./drive/MyDrive/data/val/car/2008_003755.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# car                 61.1507714
# cat                 30.4635346
# bottle              8.3470531
# bicycle             0.0143722
# bird                0.0127337
# bus                 0.0098429
# aeroplane           0.0010775
# boat                0.0006094
# [0 6 3 4 5 2 1 7]
# Image path: ./drive/MyDrive/data/val/car/2008_000251.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# aeroplane           99.7490048
# car                 0.2253247
# boat                0.0121017
# bottle              0.0073298
# bus                 0.0043801
# ...
# car                 0.0044771
# boat                0.0010178
# bird                0.0009146
# bus                 0.0004389
# aeroplane           0.0000947
# [4 7 6 1 2 3 5 0]
# Image path: ./drive/MyDrive/data/val/cat/2008_000182.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# bottle              83.6758435
# cat                 15.9233704
# car                 0.1364059
# bicycle             0.1241696
# bird                0.1096308
# boat                0.0250231
# bus                 0.0042370
# aeroplane           0.0013300
# [7 2 4 6 1 5 0 3]
# Image path: ./drive/MyDrive/data/val/cat/2008_002682.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# cat                 84.4493508
# bird                14.6229878
# bottle              0.6787501
# car                 0.1644337
# bicycle             0.0799170
# bus                 0.0025134
# aeroplane           0.0010754
# boat                0.0009783
# [7 2 4 6 1 3 5 0]
# Image path: ./drive/MyDrive/data/val/cat/2008_005421.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# cat                 99.9222517
# bird                0.0383573
# bottle              0.0291783
# car                 0.0075655
# bicycle             0.0019549
# boat                0.0003679
# bus                 0.0002210
# aeroplane           0.0000939
# [7 4 2 6 1 0 3 5]
# Image path: ./drive/MyDrive/data/val/cat/2008_005480.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# cat                 99.7030854
# bottle              0.1214732
# bird                0.0733200
# car                 0.0595595
# bicycle             0.0257480
# aeroplane           0.0081059
# boat                0.0061357
# bus                 0.0025732
# [7 4 2 0 6 5 1 3]
# Image path: ./drive/MyDrive/data/val/cat/2008_003167.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# cat                 80.4575443
# bottle              11.3246590
# bird                6.3983798
# aeroplane           1.0642380
# car                 0.6641898
# bus                 0.0509640
# bicycle             0.0356380
# boat                0.0043893
# [7 2 6 1 5 4 3 0]
# Image path: ./drive/MyDrive/data/val/cat/2008_000062.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# cat                 99.9948740
# bird                0.0028185
# car                 0.0021084
# bicycle             0.0000843
# bus                 0.0000482
# bottle              0.0000405
# boat                0.0000202
# aeroplane           0.0000068
# [7 2 4 6 5 1 0 3]
# Image path: ./drive/MyDrive/data/val/cat/2008_004422.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# cat                 99.9954343
# bird                0.0044666
# bottle              0.0000593
# car                 0.0000177
# bus                 0.0000170
# bicycle             0.0000047
# aeroplane           0.0000015
# boat                0.0000010
# [7 4 0 1 6 2 3 5]
# Image path: ./drive/MyDrive/data/val/cat/2008_000581.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# cat                 99.9628186
# bottle              0.0262140
# aeroplane           0.0040659
# bicycle             0.0024448
# car                 0.0015700
# bird                0.0014606
# boat                0.0013326
# bus                 0.0000946
# [4 7 6 2 1 5 3 0]
# Image path: ./drive/MyDrive/data/val/cat/2008_003607.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# bottle              75.1480162
# cat                 24.7839168
# car                 0.0622667
# bird                0.0055960
# bicycle             0.0001011
# bus                 0.0000496
# boat                0.0000331
# aeroplane           0.0000140
# [7 4 1 6 2 3 5 0]
# Image path: ./drive/MyDrive/data/val/cat/2008_003499.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# cat                 99.9746740
# bottle              0.0229119
# bicycle             0.0010542
# car                 0.0007303
# bird                0.0003309
# boat                0.0001502
# bus                 0.0001352
# aeroplane           0.0000088
# [4 6 7 5 1 2 3 0]
# Image path: ./drive/MyDrive/data/val/cat/2008_003228.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# bottle              99.9913812
# car                 0.0043554
# cat                 0.0030368
# bus                 0.0006359
# bicycle             0.0003097
# bird                0.0002281
# boat                0.0000210
# aeroplane           0.0000191
# [7 4 6 1 5 2 3 0]
# Image path: ./drive/MyDrive/data/val/cat/2008_001350.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# cat                 99.8290718
# bottle              0.1461743
# car                 0.0124729
# bicycle             0.0082834
# bus                 0.0019193
# bird                0.0017585
# boat                0.0002699
# aeroplane           0.0000435
# [7 4 6 3 1 2 5 0]
# Image path: ./drive/MyDrive/data/val/cat/2008_003519.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# cat                 99.9722779
# bottle              0.0200013
# car                 0.0044234
# boat                0.0025205
# bicycle             0.0003463
# bird                0.0003116
# bus                 0.0000717
# aeroplane           0.0000472
# [7 4 1 6 2 3 5 0]
# Image path: ./drive/MyDrive/data/val/cat/2008_005309.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# cat                 99.9873519
# bottle              0.0081367
# bicycle             0.0018481
# car                 0.0016498
# bird                0.0006114
# boat                0.0003079
# bus                 0.0000629
# aeroplane           0.0000365
# [7 2 4 6 0 1 3 5]
# Image path: ./drive/MyDrive/data/val/cat/2008_000306.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# cat                 99.7371435
# bird                0.2184129
# bottle              0.0303487
# car                 0.0102552
# aeroplane           0.0022698
# bicycle             0.0014969
# boat                0.0000700
# bus                 0.0000052
# [7 4 6 2 1 5 3 0]
# Image path: ./drive/MyDrive/data/val/cat/2008_004048.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# cat                 94.4312692
# bottle              2.2546882
# car                 1.5670914
# bird                1.1478039
# bicycle             0.4827320
# bus                 0.1094871
# boat                0.0063135
# aeroplane           0.0006077
# [7 4 1 2 3 5 6 0]
# Image path: ./drive/MyDrive/data/val/cat/2008_001290.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# cat                 99.9998927
# bottle              0.0000742
# bicycle             0.0000213
# bird                0.0000037
# boat                0.0000027
# bus                 0.0000005
# car                 0.0000004
# aeroplane           0.0000001
# [7 6 4 3 1 2 0 5]
# Image path: ./drive/MyDrive/data/val/cat/2008_001433.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# cat                 98.9664257
# car                 0.8921867
# bottle              0.0835988
# boat                0.0274885
# bicycle             0.0100217
# bird                0.0092524
# aeroplane           0.0083591
# bus                 0.0026748
# [7 2 6 4 1 3 5 0]
# Image path: ./drive/MyDrive/data/val/cat/2008_002681.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# cat                 96.3046074
# bird                2.6974592
# car                 0.4685756
# bottle              0.3832040
# bicycle             0.1433715
# boat                0.0012111
# bus                 0.0011719
# aeroplane           0.0004090
# [7 4 1 2 6 5 3 0]
# Image path: ./drive/MyDrive/data/val/cat/2008_001078.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# cat                 98.3192384
# bottle              1.5178626
# bicycle             0.0556390
# bird                0.0517531
# car                 0.0364757
# bus                 0.0178484
# boat                0.0007608
# aeroplane           0.0004235
# [7 4 2 6 0 3 5 1]
# Image path: ./drive/MyDrive/data/val/cat/2008_004290.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# cat                 99.7581840
# bottle              0.1787079
# bird                0.0280247
# car                 0.0220556
# aeroplane           0.0069420
# boat                0.0026837
# bus                 0.0018355
# bicycle             0.0015615
# [7 4 6 2 1 0 5 3]
# Image path: ./drive/MyDrive/data/val/cat/2008_005072.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# cat                 65.6049967
# bottle              34.3941838
# car                 0.0005436
# bird                0.0001430
# bicycle             0.0000927
# aeroplane           0.0000283
# bus                 0.0000102
# boat                0.0000030
# [7 4 6 3 2 1 5 0]
# Image path: ./drive/MyDrive/data/val/cat/2008_005288.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# cat                 99.9738038
# bottle              0.0235966
# car                 0.0009455
# boat                0.0006802
# bird                0.0005265
# bicycle             0.0003007
# bus                 0.0000768
# aeroplane           0.0000672
# [7 2 4 1 3 5 6 0]
# Image path: ./drive/MyDrive/data/val/cat/2008_000793.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# cat                 99.9735057
# bird                0.0250340
# bottle              0.0012151
# bicycle             0.0001503
# boat                0.0000628
# bus                 0.0000218
# car                 0.0000136
# aeroplane           0.0000082
# [7 4 6 1 2 5 3 0]
# Image path: ./drive/MyDrive/data/val/cat/2008_000950.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# cat                 52.2041619
# bottle              47.7867305
# car                 0.0081069
# bicycle             0.0008250
# bird                0.0001444
# bus                 0.0000357
# boat                0.0000030
# aeroplane           0.0000017
# [6 7 5 2 0 3 4 1]
# Image path: ./drive/MyDrive/data/val/cat/2008_004736.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# car                 81.6699505
# cat                 7.5232618
# bus                 6.5576248
# bird                3.6039561
# aeroplane           0.2462044
# boat                0.2124914
# bottle              0.1529161
# bicycle             0.0335955
# [7 2 6 3 0 1 4 5]
# Image path: ./drive/MyDrive/data/val/cat/2008_003557.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# cat                 61.4673674
# bird                36.9826615
# car                 1.0238349
# boat                0.2072826
# aeroplane           0.1931167
# bicycle             0.0477613
# bottle              0.0425455
# bus                 0.0354333
# [7 4 1 6 2 3 0 5]
# Image path: ./drive/MyDrive/data/val/cat/2008_004347.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# cat                 99.9994755
# bottle              0.0004031
# bicycle             0.0000462
# car                 0.0000269
# bird                0.0000243
# boat                0.0000189
# aeroplane           0.0000042
# bus                 0.0000035
# [7 4 6 0 2 3 1 5]
# Image path: ./drive/MyDrive/data/val/cat/2008_003104.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# cat                 99.9861360
# bottle              0.0086810
# car                 0.0022815
# aeroplane           0.0013220
# bird                0.0011479
# boat                0.0002048
# bicycle             0.0001858
# bus                 0.0000430
# [7 4 2 6 3 0 5 1]
# Image path: ./drive/MyDrive/data/val/cat/2008_004640.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# cat                 99.9797046
# bottle              0.0193428
# bird                0.0007534
# car                 0.0001748
# boat                0.0000100
# aeroplane           0.0000064
# bus                 0.0000060
# bicycle             0.0000034
# [7 1 5 6 3 2 4 0]
# Image path: ./drive/MyDrive/data/val/cat/2008_002234.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# cat                 100.0000000
# bicycle             0.0000025
# bus                 0.0000006
# car                 0.0000003
# boat                0.0000002
# bird                0.0000002
# bottle              0.0000002
# aeroplane           0.0000000
# [7 4 1 2 3 6 5 0]
# Image path: ./drive/MyDrive/data/val/cat/2008_000056.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# cat                 99.9999285
# bottle              0.0000733
# bicycle             0.0000023
# bird                0.0000017
# boat                0.0000006
# car                 0.0000002
# bus                 0.0000001
# aeroplane           0.0000000
# [7 4 2 1 6 5 3 0]
# Image path: ./drive/MyDrive/data/val/cat/2008_004967.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# cat                 99.9976754
# bottle              0.0009124
# bird                0.0007020
# bicycle             0.0005626
# car                 0.0000943
# bus                 0.0000325
# boat                0.0000064
# aeroplane           0.0000044
# [7 4 2 1 6 3 5 0]
# Image path: ./drive/MyDrive/data/val/cat/2008_003420.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# cat                 95.1655805
# bottle              4.7742352
# bird                0.0595111
# bicycle             0.0002557
# car                 0.0002386
# boat                0.0000789
# bus                 0.0000630
# aeroplane           0.0000417
# [7 2 6 4 1 3 5 0]
# Image path: ./drive/MyDrive/data/val/cat/2008_004540.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# cat                 99.8872578
# bird                0.0668229
# car                 0.0205018
# bottle              0.0188170
# bicycle             0.0051514
# boat                0.0011491
# bus                 0.0002279
# aeroplane           0.0000667
# [7 6 1 4 3 2 0 5]
# Image path: ./drive/MyDrive/data/val/cat/2008_000853.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# cat                 66.2648618
# car                 23.1160849
# bicycle             4.4081934
# bottle              4.3570377
# boat                1.4089843
# bird                0.2016480
# aeroplane           0.1222211
# bus                 0.1209721
# [7 4 2 6 1 3 5 0]
# Image path: ./drive/MyDrive/data/val/cat/2008_004933.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# cat                 99.9893904
# bottle              0.0073979
# bird                0.0015793
# car                 0.0005651
# bicycle             0.0005271
# boat                0.0003620
# bus                 0.0001425
# aeroplane           0.0000436
# [7 4 2 1 3 6 5 0]
# Image path: ./drive/MyDrive/data/val/cat/2008_001374.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# cat                 99.9997377
# bottle              0.0001383
# bird                0.0000734
# bicycle             0.0000319
# boat                0.0000093
# car                 0.0000052
# bus                 0.0000019
# aeroplane           0.0000009
# [7 4 2 6 1 0 3 5]
# Image path: ./drive/MyDrive/data/val/cat/2008_005270.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# cat                 99.0372419
# bottle              0.9051907
# bird                0.0543481
# car                 0.0019861
# bicycle             0.0007833
# aeroplane           0.0002361
# boat                0.0001873
# bus                 0.0000253
# [7 4 2 6 1 3 5 0]
# Image path: ./drive/MyDrive/data/val/cat/2008_005550.jpg
# Top 8 results:
# class_id            probability
# -------------------------------
# cat                 99.8494983
# bottle              0.1174306
# bird                0.0127145
# car                 0.0125022
# bicycle             0.0044085
# boat                0.0028224
# bus                 0.0003168
# aeroplane           0.0003125
